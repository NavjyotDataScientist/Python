# %% [markdown]
# <a href="https://colab.research.google.com/github/NavjyotDataScientist/Python/blob/main/14_Email_Slicer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Goal (Student Understanding)
#
# Take an email address and extract:
#
# username
#
# domain name
#
# This teaches string slicing & feature extraction.
#
# 🧠 Core Idea
#
# Raw text → meaningful parts
# Exactly how data preprocessing works.

# %%
email = "navjot.datascience@gmail.com"

username = email.split("@")[0]
domain = email.split("@")[1]

print("Email:", email)
print("Username:", username)
print("Domain:", domain)
# Out:
# Email: navjot.datascience@gmail.com
# Username: navjot.datascience
# Domain: gmail.com
